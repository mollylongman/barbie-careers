# %%
import pandas as pd
barbie_df = pd.read_csv('/Users/mollylongman/Downloads/barbie_jobs_official.csv')

# %%
barbie_df
# Out:
#                    jobs  year
# 0    business executive  1959
# 1         fashion model  1959
# 2      fashion designer  1960
# 3                singer  1960
# 4             ballerina  1961
# ..                  ...   ...
# 535         pastry chef  2023
# 536             stylist  2023
# 537       tennis player  2023
# 538   volleyball player  2023
# 539    wardrobe stylist  2023
#
# [540 rows x 2 columns]

# %%
print(barbie_df.jobs.value_counts())
# Out:
# jobs
# fashion model                                 23
# actress                                       16
# pediatrician                                  13
# veterinarian                                  12
# elementary school teacher                     11
# doctor                                        11
# pilot                                         11
# astronaut                                     10
# ballerina                                     10
# nurse                                         10
# cheerleader                                   10
# figure skater                                  9
# business executive                             9
# singer                                         9
# flight attendant                               8
# rock star                                      8
# fashion designer                               8
# chef                                           7
# soccer player                                  7
# ...

# %%
pd.set_option("display.max_rows", None)
